# %%
import math
import random

# %%
import random

def play():
    user = input(" ¿Qué vas a usar? 'piedra','papel','tijeras' ")
    computer = random.choice (['piedra', 'papel', 'tijeras'])
    
    if user == computer:
        return 'Es un Empate'
    
    if is_win(user, computer):
        return '¡Ganaste!'
    return '¡Perdiste!'

def is_win(player, opponent):
    if (player == 'piedra' and opponent == 'tijeras') or (player == 'tijeras' and opponent == 'papel') \
        or (player == 'papel' and opponent == 'tijeras'):
        return True
    
print(play())
# Out:
# ¡Ganaste!

# %%
#ciclo para repetir el juego 5 veces
for i in range(5):
    print(f"ronda{i+1}:")
    resultado = play ()
    print(resultado)
    print()
# Out:
# ronda1:
# ¡Ganaste!
#
# ronda2:
# ¡Perdiste!
#
# ronda3:
# ¡Perdiste!
#
# ronda4:
# ¡Perdiste!
#
# ronda5:
# ¡Perdiste!

# %%
# !"#$&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
import random
chars = '!"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
password =''

lengthPW = int(input('qué longitud quieres para tu PW'))

for _ in range(lengthPW):
    password += random.choice(chars)
print(password)
# Out:
# Xpx/wl*#YH/Sz4$H!k,?6QwzhPN1Vkx7C0t3Ka/TzDJ570lny/YQYa6QRB@Pp@i-bH$3KrgmKvp0B#.t-RHQI
